# %%
import io
import zipfile
import dask.dataframe as dd
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Roboto'
plt.rcParams['font.monospace'] = 'Roboto Mono'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['figure.titlesize'] = 14
plt.rcParams[ "figure.figsize"] = (20, 10)

# %%
url = 'https://www.truefx.com/download/67/january/3149/eurusd-2020-01.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile( io.BytesIO(r.content) )
data = dd.from_pandas( pd.read_csv(z.open(zipfile.ZipFile.namelist(z)[0]), header = None), npartitions = 1)

url = 'https://www.truefx.com/download/68/february/3185/eurusd-2020-02.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile( io.BytesIO(r.content) )
data = data.append( dd.from_pandas( pd.read_csv(z.open(zipfile.ZipFile.namelist(z)[0]), header = None), npartitions = 1) )

url = 'https://www.truefx.com/download/69/march/3241/eurusd-2020-03.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile( io.BytesIO(r.content) )
data = data.append( dd.from_pandas( pd.read_csv(z.open(zipfile.ZipFile.namelist(z)[0]), header = None), npartitions = 1) )

url = 'https://www.truefx.com/download/70/april/3304/eurusd-2020-04.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile( io.BytesIO(r.content) )
data = data.append( dd.from_pandas( pd.read_csv(z.open(zipfile.ZipFile.namelist(z)[0]), header = None), npartitions = 1) )

url = 'https://www.truefx.com/download/71/may/3429/eurusd-2020-05.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile( io.BytesIO(r.content) )
data = data.append( dd.from_pandas( pd.read_csv(z.open(zipfile.ZipFile.namelist(z)[0]), header = None), npartitions = 1) )

url = 'https://www.truefx.com/download/72/june/3473/eurusd-2020-06.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile( io.BytesIO(r.content) )
data = data.append( dd.from_pandas( pd.read_csv(z.open(zipfile.ZipFile.namelist(z)[0]), header = None), npartitions = 1) )

# %%
data
# Out:
# Dask DataFrame Structure:
#                     0       1        2        3
# npartitions=6
#                object  object  float64  float64
#                   ...     ...      ...      ...
# ...               ...     ...      ...      ...
#                   ...     ...      ...      ...
#                   ...     ...      ...      ...
# Dask Name: concat, 26 tasks

# %%
data = data.compute()
data.to_csv('data.csv')

# %%
data
# Out:
#                0                      1        2        3
# 0        EUR/USD  20200101 22:01:18.475  1.12046  1.12203
# 1        EUR/USD  20200101 22:01:18.585  1.12083  1.12167
# 2        EUR/USD  20200101 22:01:18.636  1.12047  1.12204
# 3        EUR/USD  20200101 22:01:18.693  1.12083  1.12167
# 4        EUR/USD  20200101 22:01:19.170  1.12094  1.12166
# ...          ...                    ...      ...      ...
# 3809249  EUR/USD  20200630 23:59:49.918  1.12339  1.12344
# 3809250  EUR/USD  20200630 23:59:50.038  1.12338  1.12343
# 3809251  EUR/USD  20200630 23:59:59.043  1.12337  1.12340
# 3809252  EUR/USD  20200630 23:59:59.047  1.12335  1.12340
# 3809253  EUR/USD  20200630 23:59:59.172  1.12334  1.12339
#
# [20907128 rows x 4 columns]

# %%
data = pd.read_csv('data.csv', index_col = 0)
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
def count_zeros(x):
    return len(x[x==0])

def nonzero_mean(x):
    return x[x != 0].mean()

def up_tick(x):
    u = x - x.shift(1)
    return len( u[u>0] )

def down_tick(x):
    u = x - x.shift(1)
    return len( u[u<0] ) 
    
def tick_count(x):
    return len(x)

# %%
data.columns = ['currency_pair', 'timestamp', 'bid', 'ask' ]
data['all_spreads'] = data.ask - data.bid
data['non_zero_spreads'] = data.ask - data.bid
data['zero_spreads'] = data.ask - data.bid
data['mid'] = ( data.ask + data.bid) / 2
data['high'] = data.mid
data['low'] = data.mid
data['ask_up'] = data.ask
data['ask_down'] = data.ask
data['bid_up'] = data.bid
data['bid_down'] = data.bid
data['number_of_ticks'] = data.bid

data.index = pd.to_datetime( data.timestamp )

# %%
#plt.plot(data.ask_up)
#plt.scatter(data.ask_up, data.pips)
data

# %%
aggregation = { 'currency_pair': 'last', 
                'timestamp':'last', 
                'bid': 'last', 
                'ask': 'last',
                'mid': 'last', 
                'all_spreads': 'mean', 
                'non_zero_spreads': nonzero_mean, 
                'zero_spreads': count_zeros,
                'low': 'min',
                'high': 'max',
                'bid_up': up_tick,
                'bid_down': down_tick,
                'ask_up': up_tick,
                'ask_down': down_tick,
                'number_of_ticks': tick_count
              }
data = data.resample('1T').agg( aggregation )
data['returns'] = data.mid.pct_change()
data = data[1:]
data['hour'] = [ t.hour for t in data.index ]
data['min'] = [ t.minute for t in data.index ]
data['date'] = [ t.date() for t in data.index ]

# use mid price???
data['pips'] = data.ask - data.ask.shift(1)
data['trading_hours'] = 0
data['trading_hours'][data.hour.between(6,20)] = 1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['trading_hours'] = 0
data['trading_hours'][data.hour.between(6,20)] = 1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(len(data))
data[ data['mid'].isna() ]
# Out:
# 260758
#                     currency_pair timestamp  bid  ask  mid  all_spreads  \
# timestamp
# 2020-01-01 22:12:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-01-01 22:14:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-01-01 23:34:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-01-01 23:37:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-01-02 21:28:00           NaN       NaN  NaN  NaN  NaN          NaN
# ...                           ...       ...  ...  ...  ...          ...
# 2020-06-28 21:02:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-06-28 21:05:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-06-28 21:29:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-06-30 21:03:00           NaN       NaN  NaN  NaN  NaN          NaN
# 2020-06-30 23:02:00           NaN       NaN  NaN  NaN  NaN          NaN
#
#                      non_zero_spreads  zero_spreads  low  high  ...  bid_down  \
# ...

# %%
data.dropna(inplace = True)
data.to_csv('data.csv')

# %%
df = pd.read_csv('data.csv')
#df = data.copy()
data = None

# %%
df.date = pd.to_datetime(df.date)

# %%
#df['trading_hours'] = 1
plt.scatter(df.ask_up/df.number_of_ticks,df.returns )

#plt.hist(df.non_zero_spreads, bins = 100)

# %%
d = '2020-03-26'

# %%
plt.plot(df.bid_down[df.date == pd.to_datetime(d)]/df.number_of_ticks[df.date == pd.to_datetime(d)], alpha = 0.5)
plt.plot((df.bid_down[df.date == pd.to_datetime(d)]/df.number_of_ticks[df.date == pd.to_datetime(d)]).rolling(30).mean())

# %%
plt.plot(df[df.date == pd.to_datetime(d)].pips / df[df.date == pd.to_datetime(d)].number_of_ticks)

# %%
d = '2020-03-27'
plt.plot(df[df.date == pd.to_datetime(d)].mid)
plt.plot(df[df.date == pd.to_datetime(d)].mid.rolling(15).mean())
plt.plot(df[df.date == pd.to_datetime(d)].mid.rolling(60).mean())
plt.plot(df[df.date == pd.to_datetime(d)].mid.rolling(240).mean())

# %%
(df.sma15 / df.sma60 - 1) * 100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 178820   -0.002255
# 178821   -0.002092
# 178822   -0.002040
# 178823   -0.001951
# 178824   -0.002121
# Length: 178825, dtype: float64

# %%
def sma_strategy(df, short, long, thresh = None, neg = 1):
    df[f'sma{short}'] = df.mid.rolling(short).mean()
    df[f'sma{long}'] = df.mid.rolling(long).mean()
    df['sma_signal'] = df[f'sma{short}'] - df[f'sma{long}']
    if thresh == None:
        df['sma_signal'][df['sma_signal']<0] = -1
        df['sma_signal'][df['sma_signal']>0] =  1
    else:
        df['sma_signal'][df['sma_signal']<-thresh] = -1
        df['sma_signal'][df['sma_signal']>thresh] =  1
        df['sma_signal'][ np.abs(df['sma_signal']) != 1] = 0
    df['sma_signal'] = df['sma_signal'] * neg
    return df

# %%
def sma_price_strategy(df, sma, thresh = None, neg = 1):
    df[f'sma{sma}'] = df.mid.rolling(sma).mean()
    df['sma_signal'] = df[f'sma{sma}'] - df.mid
    if thresh == None:
        df['sma_signal'][df['sma_signal']<0] = -1
        df['sma_signal'][df['sma_signal']>0] =  1
    else:
        df['sma_signal'][df['sma_signal']<-thresh] = -1
        df['sma_signal'][df['sma_signal']>thresh] =  1
        df['sma_signal'][ np.abs(df['sma_signal']) != 1] = 0
    df['sma_signal'] = df['sma_signal'] * neg
    return df

# %%
s = 1
#df = sma_strategy(df, 50, 200, thresh = 0.0000, neg = -1 )
df = sma_price_strategy(df, 15, thresh = 0.005, neg = 1 )
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.plot(( df['sma_signal'].shift(s) * df.pips ).cumsum())

# %%
df.sma_signal = df.sma_signal * df.trading_hours
trade_count = 0
for i, j in enumerate(df['sma_signal']):
    if j == np.nan:
        pass
    else:
        if j != df['sma_signal'].iloc[i-1]:
            trade_count += 1
        else:
            pass
print(trade_count)
# Out:
# 6

# %%
(df['sma_signal'].shift(s) * df.pips ).cumsum().iloc[-1] * 10000 / trade_count
# Out:
# 11.983333333333382

# %%
m = df['sma_signal'].shift(s) * df.returns

# %%
np.sqrt(252 * 24 * 3) * m[m!=0].mean() / m[m!=0].std()
# Out:
# 3443.181171588498

# %%
(df['sma_signal'].shift(s) * df.pips).cumsum().iloc[-1] * 10000 - trade_count * 1
# Out:
# 65.90000000000029

# %%
(df['sma_signal'] * df.pips.shift(s)).cumsum()
# Out:
# 0             NaN
# 1         0.00000
# 2         0.00000
# 3         0.00000
# 4         0.00000
#            ...
# 178820   -0.00244
# 178821   -0.00244
# 178822   -0.00244
# 178823   -0.00244
# 178824   -0.00244
# Length: 178825, dtype: float64

# %%
(df['sma_signal'] * df.pips.shift(s) ).cumsum()
# Out:
# 0         0.00000
# 1         0.00000
# 2         0.00000
# 3         0.00000
# 4         0.00000
#            ...
# 178820    0.12738
# 178821    0.12738
# 178822    0.12738
# 178823    0.12738
# 178824    0.12738
# Length: 178825, dtype: float64

# %%
fig, ax1 = plt.subplots()
ax1.plot( df.mid[df.date == d][df.trading_hours == 1] )
ax2 = ax1.twinx()
ax2.plot(df['half_hour'][df.date == d][df.trading_hours == 1], color = 'red', alpha = 0.5)

# %%
d = '2020-04-29'
# %matplotlib inline


for d in df.date:
    fig, ax1 = plt.subplots()
    ax1.plot( df.mid[df.date == d][df.trading_hours == 1] )
    ax2 = ax1.twinx()
    ax2.plot(df['half_hour'][df.date == d][df.trading_hours == 1], color = 'red', alpha = 0.5)
    plt.show()
    time.sleep(5)
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-767-cbf3a6cb6f54> in <module>
#       9     ax2.plot(df['half_hour'][df.date == d][df.trading_hours == 1], color = 'red', alpha = 0.5)
#      10     plt.show()
# ---> 11     time.sleep(5)
#      12     plt.close()
#      13
#
# KeyboardInterrupt:

# %%
df['half_hour'] = [ 1 if t.minute == 30 else 0 for t in df.timestamp ]

# %%
df.mid[df.date == d][df.trading_hours == 1]
# Out:
# 469     1.120450
# 470     1.120530
# 471     1.120480
# 472     1.120600
# 473     1.120655
#           ...
# 1364    1.116925
# 1365    1.116835
# 1366    1.116770
# 1367    1.116820
# 1368    1.116925
# Name: mid, Length: 900, dtype: float64

# %%
# %matplotlib inline
import time

plt.ion()

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 8

d = df.date[0]
fig, ax1 = plt.subplots()
ax1.plot( df.mid[df.date == d][df.trading_hours == 1] )
ax2 = ax1.twinx()
ax2.plot(df['half_hour'][df.date == d][df.trading_hours == 1], color = 'red', alpha = 0.5)



fig.canvas.draw()



for d in df.date[1:]:
    # update data 
   
    # re-plot area 1 of fig1  
    ax1.clear()
    ax1.plot(df.mid[df.date == d][df.trading_hours == 1])
    
    # re-plot area 2 of fig1  
    ax2.clear()
    ax2.plot(df['half_hour'][df.date == d][df.trading_hours == 1], color = 'red', alpha = 0.5)

    # redraw fig 1 
    fig.canvas.draw()

    time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-762-cc3cbee44f8a> in <module>
#      28
#      29     # re-plot area 2 of fig1
# ---> 30     ax2.clear()
#      31     ax2.plot(df['half_hour'][df.date == d][df.trading_hours == 1], color = 'red', alpha = 0.5)
#      32
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in clear(self)
#    1111     def clear(self):
#    1112         """Clear the axes."""
# -> 1113         self.cla()
#    1114
#    1115     def get_facecolor(self):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#     975
#     976         for name, spine in self.spines.items():
# --> 977             spine.cla()
#     978
#     979         self.ignore_existing_data_limits = True
#
# ...

# %% [markdown]
# ### Strategy

# %%
df = data.copy()
df['trading_hours'] = 1
momentum = 60
holding_period = 480
round_trip = 1.2
spread_cutoff = 0.00002

# %%
df[f'returns_{momentum}'] = df.mid / df.mid.shift(momentum) - 1
df[f'mom{momentum}'] = df[ f'returns_{momentum}' ]
df[f'mom{momentum}'][ df[f'mom{momentum}'] <= 0 ] = -1
df[f'mom{momentum}'][ df[f'mom{momentum}'] >= 0 ] = 1
#df[f'mom{momentum}'][ np.abs(df[f'mom{momentum}']) != 1 ] = 0
#df[f'mom{momentum}'] *= -1

df.dropna(inplace = True)
df.reset_index(inplace = True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
plt.plot( df[f'mom{momentum}'] )

# %%
df['spread_below_000001'] = 0
df['spread_below_000001'][df.non_zero_spreads <= spread_cutoff ] = 1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#df[ df['spread_below_000001'] == 1 ]

# %%
# clean signal
spread_signal = 'spread_below_000001'
momentum_signal = f'mom{momentum}'
count = 0
for i, j in enumerate( df[spread_signal] ): 
    if np.abs( j ) == 1 and count == 0:
        try:
            df.loc[i, spread_signal] = 0
            df.loc[i+1:i+holding_period, spread_signal] = 1 * df[momentum_signal].loc[i] #* df['trading_hours'].iloc[i] 
            count = holding_period
        except:
            df[spread_signal].loc[i+1:, spread_signal] = 1 * df[momentum_signal].loc[i] #* df['trading_hours'].iloc[i] 
            break
    else:
        if i != 0:
            #print(np.abs( df[spread_signal].loc[i-1] ))
            if np.abs( df[spread_signal].loc[i] ) == 1:
                count -= 1

#df[spread_signal][df.hour >= 20] = 0
#df[spread_signal][df.hour <= 6] = 0

# %%
pip_profit = df.spread_below_000001 * df.pips * 10000
transaction_costs = np.abs(df.spread_below_000001) / holding_period * round_trip

# %%
m = df[(df.spread_below_000001 != 0)].index
mean_pips = pip_profit.loc[m].mean() * holding_period
std_pips = (pip_profit.loc[m] ).std() * np.sqrt( holding_period )

# %%
#df[ df[spread_signal] != 0 ]

# %%
print('Pre-transaction costs')
print('Mean pips:', mean_pips)
print('Std pips:', std_pips)
print('Total pips:', pip_profit.sum())
print('\n')
print('After-transaction costs')
print('Mean pips:', (pip_profit - transaction_costs).mean() * holding_period )
print('Total pips:', (pip_profit - transaction_costs).sum())
print('\n')
print('Number of trades:', len(m) / holding_period)
# Out:
# Pre-transaction costs
# Mean pips: 0.8021151108395196
# Std pips: 17.8659426632928
# Total pips: 49.299999999974375
#
#
# After-transaction costs
# Mean pips: -0.3773798424693155
# Total pips: -24.45500000002488
#
#
# Number of trades: 61.4625

# %%
plt.plot( df.pips.cumsum() * 10000, label = 'actual pips', alpha = 0.2)
plt.plot( pip_profit.cumsum(), label = 'pre transaction costs')
plt.plot( ( pip_profit - transaction_costs ).cumsum(), label = 'after transaction costs')
plt.legend()

# %%
plt.plot(df.returns.rolling(60).std())

# %% [markdown]
# ## Stoploss

# %%
pip_profit = df.spread_below_000001 * df.pips * 10000

pip_trade = pip_profit.copy()
for i, j in enumerate(pip_trade):
    if j != 0:
        pip_trade.iloc[i] += pip_trade.iloc[i-1]

# %%
stoploss = -20
count = 0
for i, j in enumerate(pip_trade):
    if j < stoploss and count == 0:
        pip_profit.loc[i] = -stoploss
        pip_profit.loc[i+1:pip_profit.loc[i:][pip_profit == 0].index[0]] = 0
        count = len(pip_profit.iloc[i+1:pip_profit.loc[i+1:][pip_profit == 0].index[0]-1])
    elif count != 0:
        count -= 1

# %%
# check if everything is set to zero correctly

# %%
m = df[(df.spread_below_000001 != 0) ].index
mean_pips = pip_profit.loc[m].mean() * holding_period
std_pips = (pip_profit.loc[m] ).std() * np.sqrt( holding_period )

# %%
print('Pre-transaction costs')
print('Mean pips:', mean_pips)
print('Std pips:', std_pips)
print('Total pips:', pip_profit.sum())
print('\n')
print('After-transaction costs')
print('Mean pips:', (pip_profit - transaction_costs).mean() * holding_period )
print('Total pips:', (pip_profit - transaction_costs).sum())
print('\n')
print('Number of trades:', len(m) / holding_period)
# Out:
# Pre-transaction costs
# Mean pips: 92.79024390243916
# Std pips: 50.666880568176744
# Total pips: 3804.4000000000115
#
#
# After-transaction costs
# Mean pips: 42.85806676600064
# Total pips: 3755.2000000000116
#
#
# Number of trades: 41.0

# %%
plt.plot( pip_profit.cumsum(), label = 'pre transaction costs')
plt.plot( ( pip_profit - transaction_costs ).cumsum(), label = 'after transaction costs')
plt.legend()

# %%
# exit position when past 20

# %%
pip_trade = pip_profit.copy()
for i, j in enumerate(pip_trade):
    if j != 0:
        pip_trade.iloc[i] += pip_trade.iloc[i-1]

# %%
plt.plot(pip_profit.cumsum())

# %%
i

# %%
plt.hist(df.returns_60, bins = 100)
# Out:
# (array([3.000e+00, 3.000e+00, 6.000e+00, 7.000e+00, 6.000e+00, 5.000e+00,
#         4.000e+00, 6.000e+00, 8.000e+00, 1.100e+01, 1.000e+01, 6.000e+00,
#         4.000e+00, 9.000e+00, 7.000e+00, 8.000e+00, 1.200e+01, 1.400e+01,
#         1.700e+01, 2.200e+01, 3.200e+01, 3.800e+01, 4.300e+01, 7.100e+01,
#         8.300e+01, 9.800e+01, 1.140e+02, 1.440e+02, 1.510e+02, 2.250e+02,
#         2.630e+02, 3.630e+02, 4.650e+02, 4.790e+02, 5.800e+02, 6.940e+02,
#         9.080e+02, 1.078e+03, 1.215e+03, 1.499e+03, 1.732e+03, 1.906e+03,
#         2.186e+03, 2.459e+03, 2.326e+03, 2.209e+03, 1.927e+03, 1.579e+03,
#         1.201e+03, 9.320e+02, 7.880e+02, 5.820e+02, 5.380e+02, 4.200e+02,
#         3.600e+02, 2.770e+02, 2.240e+02, 1.980e+02, 1.520e+02, 1.220e+02,
#         1.060e+02, 8.900e+01, 7.400e+01, 6.900e+01, 4.700e+01, 2.100e+01,
#         1.800e+01, 2.500e+01, 2.400e+01, 2.700e+01, 3.100e+01, 3.500e+01,
#         2.600e+01, 1.100e+01, 1.100e+01, 1.200e+01, 7.000e+00, 9.000e+00,
# ...
